# %%
# Step 1: Install required libraries
# !pip install datasets pandas matplotlib

# Step 2: Import libraries
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt

# Step 3: Load the Abirate/english_quotes dataset
dataset = load_dataset("Abirate/english_quotes")

# Step 4: Convert to pandas DataFrame
df = pd.DataFrame(dataset['train'])

# Step 5: Display basic info
print("Dataset Shape:", df.shape)
df.head()
# Out:
# ...
# Dataset Shape: (2508, 3)
#                                                quote                 author  \
# 0     “Be yourself; everyone else is already taken.”            Oscar Wilde
# 1  “I'm selfish, impatient and a little insecure....         Marilyn Monroe
# 2  “Two things are infinite: the universe and hum...        Albert Einstein
# 3                   “So many books, so little time.”            Frank Zappa
# 4  “A room without books is like a body without a...  Marcus Tullius Cicero
#
#                                                 tags
# 0  [be-yourself, gilbert-perreira, honesty, inspi...
# 1  [best, life, love, mistakes, out-of-control, t...
# 2  [human-nature, humor, infinity, philosophy, sc...
# 3                                     [books, humor]
# 4                              [books, simile, soul]

# %%
# Step 6: Top 10 authors with the most quotes
top_authors = df['author'].value_counts().head(10)

# Plotting
plt.figure(figsize=(10, 6))
top_authors.plot(kind='bar', color='skyblue')
plt.title("Top 10 Authors with the Most Quotes")
plt.xlabel("Author")
plt.ylabel("Number of Quotes")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Step 7: Most frequent tags
from collections import Counter

# Flatten all tags into a single list
all_tags = sum(df['tags'], [])

# Count tag frequencies
tag_counts = Counter(all_tags)

# Top 15 most common tags
top_tags = tag_counts.most_common(15)

# Separate tags and their counts
tags, counts = zip(*top_tags)

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(tags, counts, color='lightgreen')
plt.title("Top 15 Most Frequent Tags")
plt.xlabel("Tags")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

# Combine all quotes into a single string
text = ' '.join(df['quote'])

# Add custom stopwords if necessary
stopwords = set(STOPWORDS)

# Generate the word cloud
wordcloud = WordCloud(width=1200, height=600, background_color='white',
                      stopwords=stopwords, colormap='viridis').generate(text)

# Display the word cloud
plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Most Common Words in Quotes", fontsize=16)
plt.show()

# %%
import seaborn as sns

# %%
# Top 15 most quoted authors
top_authors = df['author'].value_counts().head(15)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_authors.index, y=top_authors.values, palette='magma')
plt.title("Top 15 Most Quoted Authors")
plt.xlabel("Authors")
plt.ylabel("Number of Quotes")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/nl/h32y1g9s3yj85pfnr0n7zqbh0000gn/T/ipykernel_70998/2959345330.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_authors.index, y=top_authors.values, palette='magma')

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')
quotes_list = [
    "The only way to do great work is to love what you do.",
    "Life is what happens when you're busy making other plans.",
    "Success usually comes to those who are too busy to be looking for it."
]

quote_embeddings = model.encode(quotes_list)
# Out:
# /Users/krizzkamaliyagmail.com/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')  # or your fine-tuned model
quotes = df['quote'].tolist()
quote_embeddings = model.encode(quotes, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
pip install faiss-cpu
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 3.3 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import faiss
import numpy as np

quote_embeddings = np.array(quote_embeddings).astype('float32')
index = faiss.IndexFlatL2(quote_embeddings.shape[1])
index.add(quote_embeddings)

# %%
def search_quote(query, top_k=5):
    query_embedding = model.encode([query])
    D, I = index.search(np.array(query_embedding).astype('float32'), top_k)
    return df.iloc[I[0]]

# %%
query = "happiness and life"
results = search_quote(query)

print("🔍 Top Relevant Quotes:")
for i, row in results.iterrows():
    print(f"\nQuote: {row['quote']}\nAuthor: {row['author']}")
# Out:
# 🔍 Top Relevant Quotes:
#
# Quote: “The purpose of life is not to be happy. It is to be useful, to be honorable, to be compassionate, to have it make some difference that you have lived and lived well.”
# Author: Ralph Waldo Emerson
#
# Quote: “Happiness is the consequence of personal effort. You fight for it, strive for it, insist upon it, and sometimes even travel around the world looking for it. You have to participate relentlessly in the manifestations of your own blessings. And once you have achieved a state of happiness, you must never become lax about maintaining it. You must make a mighty effort to keep swimming upward into that happiness forever, to stay afloat on top of it.”
# Author: Elizabeth Gilbert,
#
# Quote: “Happiness is when what you think, what you say, and what you do are in harmony.”
# Author: Mahatma Gandhi
#
# ...

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad")

def answer_question(question, top_k=5):
    retrieved_quotes = search_quote(question, top_k=top_k)
    context = " ".join(retrieved_quotes['quote'].tolist())
    result = qa_model(question=question, context=context)
    return result['answer'], context
# Out:
# config.json:   0%|          | 0.00/451 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/265M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
question = "What is the key to happiness?"
answer, context = answer_question(question)

print("🤖 Answer:", answer)
# Out:
# 🤖 Answer: personal effort

# %%
from sentence_transformers import SentenceTransformer, InputExample, losses
from torch.utils.data import DataLoader

train_examples = [
    InputExample(texts=["Stay strong", "Be brave", "I'm tired"]),  # A, P, N
    # Add more triplets
]

model = SentenceTransformer("all-MiniLM-L6-v2")
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)
train_loss = losses.TripletLoss(model=model)

model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=1)
model.save("models/fine-tuned-model")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 13
#      10 train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)
#      11 train_loss = losses.TripletLoss(model=model)
# ---> 13 model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=1)
#      14 model.save("models/fine-tuned-model")
#
# File ~/anaconda3/lib/python3.11/site-packages/sentence_transformers/fit_mixin.py:321, in FitMixin.fit(self, train_objectives, evaluator, epochs, steps_per_epoch, scheduler, warmup_steps, optimizer_class, optimizer_params, weight_decay, evaluation_steps, output_path, save_best_model, max_grad_norm, use_amp, callback, show_progress_bar, checkpoint_path, checkpoint_save_steps, checkpoint_save_total_limit, resume_from_checkpoint)
#     315 # Transformers renamed `evaluation_strategy` to `eval_strategy` in v4.41.0
#     316 eval_strategy_key = (
# ...
